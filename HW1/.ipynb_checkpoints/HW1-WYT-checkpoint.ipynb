# %% [markdown]
# # Question 1

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# Read the data
churn = pd.read_csv('Customer-Churn.csv')

# %%
X = churn.drop(['Churn'],axis=1)
y = churn['Churn']

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y.ravel(),test_size=0.30)

# %%
churn_train = x_train.copy()
churn_train['Churn'] = pd.Series(y_train, index=churn_train.index)

# %% [markdown]
# **Here, we plot the univariate distribution regarding impact on churning**

# %%
categorical = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
numeric = ['tenure', 'MonthlyCharges', 'TotalCharges']
for i in numeric:
    sns.set(style="whitegrid")
    yes = churn_train.groupby("Churn").get_group("Yes")
    no = churn_train.groupby("Churn").get_group("No")
    f, axes = plt.subplots(1, 2, figsize=(10, 10), sharey=True)
    f.suptitle(i)
    yes_array = pd.Series(list(yes[i]), name="Churn")
    no_array = pd.Series(list(no[i]), name="No Churn")
    sns.distplot(yes_array,ax = axes[0])
    sns.distplot(no_array,ax = axes[1])
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %%
for j in categorical:
    sns.set(style="whitegrid")
    fig, ax = plt.subplots(1,1)
    ax = sns.countplot(x = j,hue = "Churn", data=churn_train)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Question 2

# %%
churn_dummies = pd.get_dummies(churn,columns = [ 'SeniorCitizen', 'Partner', 'Dependents',
        'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod','Churn'])
