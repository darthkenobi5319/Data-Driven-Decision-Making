# %% [markdown]
# @Author: Harry Zhenghan Zhang

# %% [markdown]
# # Question 1

# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
import sklearn
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.linear_model import LinearRegression,LogisticRegression

# %%
# Read the data
churn = pd.read_csv('Customer-Churn.csv')
# Check data shape
print(churn.shape)
# Out:
# (7032, 21)

# %%
# select all column names except user ID
columns = np.array(churn.columns)[1:]

# %%
# check
print(columns)
# Out:
# ['gender' 'SeniorCitizen' 'Partner' 'Dependents' 'tenure' 'PhoneService'
#  'MultipleLines' 'InternetService' 'OnlineSecurity' 'OnlineBackup'
#  'DeviceProtection' 'TechSupport' 'StreamingTV' 'StreamingMovies'
#  'Contract' 'PaperlessBilling' 'PaymentMethod' 'MonthlyCharges'
#  'TotalCharges' 'Churn']

# %%
# perform train test split
# first seperate dependent variable
X = churn.drop(['Churn'],axis=1)
y = churn['Churn']

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y.ravel(),test_size=0.30)

# %%
# preparation for plotting
churn_train = x_train.copy()
churn_train['Churn'] = pd.Series(y_train, index=churn_train.index)

# %%
# This information comes from variable "columns"
categorical = ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
numeric = ['tenure', 'MonthlyCharges', 'TotalCharges']

# %%
# Sub-plots for univariate distributions with regard to churning
sns.set(style="white", palette="muted", color_codes=True)
# seperate two dataframes with all yes and all no in "Churn"
yes_churn = churn_train.groupby("Churn").get_group("Yes")
no_churn = churn_train.groupby("Churn").get_group("No")
## Numeric Values
for i in numeric:
    f, axes = plt.subplots(1, 2, figsize=(10, 5), sharey=True)
    f.suptitle("Churn related to "+i)
    yes = pd.Series(list(yes_churn[i]), name="Yes")
    no = pd.Series(list(no_churn[i]), name="No")
    sns.distplot(yes,kde=False,color = 'blue', ax = axes[0])
    sns.distplot(no,kde=False, color = 'blue', ax = axes[1])
## Categorical Values
for j in categorical:
    sns.set(style="whitegrid")
    fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    ax = sns.countplot(x = j,hue = "Churn", data=churn_train)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# # Question 2
# As we can see, gender does not matter. Therefore we drop gender. Also, we would keep n-1 columns for factors with n levels.

# %%
# get dummy variables for categorical values
churn_dummies = pd.get_dummies(churn,columns = [ 'SeniorCitizen', 'Partner', 'Dependents',
        'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod','Churn'])

# %%
churn_dummies.columns
# Out:
# Index(['customerID', 'gender', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'SeniorCitizen_0', 'SeniorCitizen_1', 'Partner_No', 'Partner_Yes',
#        'Dependents_No', 'Dependents_Yes', 'PhoneService_No',
#        'PhoneService_Yes', 'MultipleLines_No',
#        'MultipleLines_No phone service', 'MultipleLines_Yes',
#        'InternetService_DSL', 'InternetService_Fiber optic',
#        'InternetService_No', 'OnlineSecurity_No',
#        'OnlineSecurity_No internet service', 'OnlineSecurity_Yes',
#        'OnlineBackup_No', 'OnlineBackup_No internet service',
#        'OnlineBackup_Yes', 'DeviceProtection_No',
#        'DeviceProtection_No internet service', 'DeviceProtection_Yes',
#        'TechSupport_No', 'TechSupport_No internet service', 'TechSupport_Yes',
#        'StreamingTV_No', 'StreamingTV_No internet service', 'StreamingTV_Yes',
#        'StreamingMovies_No', 'StreamingMovies_No internet service',
# ...

# %%
test = np.array(churn_dummies['InternetService_No'] == churn_dummies['OnlineBackup_No internet service'])

# %%
compare = np.ones_like(test, dtype=bool)

# %%
np.array_equal(test,compare)
# Out:
# True

# %%
churn_dummies.head()
# Out:
#    customerID  gender  tenure  MonthlyCharges  TotalCharges  SeniorCitizen_0  \
# 0  2967-MXRAV    Male       1           18.80         18.80                1
# 1  8992-CEUEN  Female       1           18.85         18.85                1
# 2  9318-NKNFC    Male       1           18.85         18.85                1
# 3  9975-SKRNR    Male       1           18.90         18.90                1
# 4  1423-BMPBQ  Female       1           19.00         19.00                1
#
#    SeniorCitizen_1  Partner_No  Partner_Yes  Dependents_No  ...  \
# 0                0           0            1              0  ...
# 1                0           1            0              1  ...
# 2                0           1            0              1  ...
# 3                0           1            0              1  ...
# 4                0           0            1              0  ...
#
#    Contract_One year  Contract_Two year  PaperlessBilling_No  \
# ...

# %%
# drop variables
churn_dummies = churn_dummies.drop(['gender','customerID','MultipleLines_No phone service','OnlineSecurity_No internet service',
                                    'OnlineBackup_No internet service','DeviceProtection_No internet service',
                                    'TechSupport_No internet service', 'StreamingTV_No internet service',
                                    'StreamingMovies_No internet service','Churn_No','SeniorCitizen_0','Partner_No', 'Dependents_No',
                                   'PhoneService_No','MultipleLines_No','OnlineSecurity_No','OnlineBackup_No','DeviceProtection_No','PaperlessBilling_No',
                                   'TechSupport_No', 'StreamingTV_No','StreamingMovies_No'], axis=1)

# %%
corr = churn_dummies.corr()
items=list(corr.columns)

# %%
## Find out columns with high correlation (greater than 0.8)
for i in items:
    for j in items:
        if i != j: 
            if np.absolute(corr[i][j]) >= 0.8:
                print(i,j)
# Out:
# tenure TotalCharges
# TotalCharges tenure

# %% [markdown]
# As we have seen, tenure and totalCharges are highly correlated, therefore, we compare between having or not having these columns

# %%
# Dropping tenure
# seperate dependent variable and perform train-test split
churn_new = churn_dummies.drop(['tenure'],axis=1)
X = churn_new.drop(['Churn_Yes'],axis=1)
y = churn_new['Churn_Yes']
x_train, x_test, y_train, y_test = train_test_split(X,y.ravel(),test_size=0.30)

# Logistic regression with grid search
param_test = {
        'C':np.logspace(-3,0)
    }

estimator = LogisticRegression(solver='lbfgs',max_iter = 10000)
gsearch = GridSearchCV(estimator, param_grid = param_test, cv=10)
gsearch.fit(x_train,y_train)
# fit a model with optimal parameters
# calculate the loss
clf = LogisticRegression(C = gsearch.best_params_['C'],solver='lbfgs',max_iter = 10000)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8042654028436019

# %%
# Dropping TotalCharges
# seperate dependent variable and perform train-test split
churn_new = churn_dummies.drop(['TotalCharges'],axis=1)
X = churn_new.drop(['Churn_Yes'],axis=1)
y = churn_new['Churn_Yes']
x_train, x_test, y_train, y_test = train_test_split(X,y.ravel(),test_size=0.30)

# Logistic regression with grid search
param_test = {
        'C':np.logspace(-3,0)
    }

estimator = LogisticRegression(solver='lbfgs',max_iter = 10000)
gsearch = GridSearchCV(estimator, param_grid = param_test, cv=10)
gsearch.fit(x_train,y_train)
# fit a model with optimal parameters
# calculate the score
clf = LogisticRegression(C = gsearch.best_params_['C'],solver='lbfgs',max_iter = 10000)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8151658767772512

# %% [markdown]
# The testing shows that dropping the TotalCharges column got the best accuracy of .8151658767772512
#
# Therefore, we would also drop this column in the following tests.

# %% [markdown]
# # Question 3

# %% [markdown]
# First, we would like to standardize all non-categorical values, so that Euclidian distance may be calculated more effectivly.

# %%
from sklearn.preprocessing import StandardScaler
# scale the data for SVC
x_train_standard = x_train.copy()
x_train_standard[['tenure','MonthlyCharges']] = StandardScaler().fit_transform(x_train[['tenure','MonthlyCharges']])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %% [markdown]
# Then, we use gridsearch to identify which parameters are best for SVC. The hyperparameters tuned are: kernels, gamma, C and degree.

# %%
x_test_standard = x_test.copy()
x_test_standard[['tenure','MonthlyCharges']] = StandardScaler().fit_transform(x_test[['tenure','MonthlyCharges']])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
from sklearn.svm import SVC
# fit a model with optimal parameters
# calculate the accuracy
score = 0
poly = 0
for i in range(6): 
    clf = SVC(degree = i+1 , kernel = 'poly',gamma = 'auto')
    clf.fit(x_train_standard,y_train)
    y_pred = clf.predict(x_test_standard)
    new_score = accuracy_score(y_test,y_pred)
    if new_score > score:
        score = new_score
        ploy = i + 1
print(score,ploy,sep = ' ')
# Out:
# 0.809478672985782 1

# %% [markdown]
# polynomial kernel with degree 1 is the linear kernel

# %%
# fit a model with rbf kernel
# calculate the accuracy

clf = SVC(kernel = 'rbf',gamma = 'auto')
clf.fit(x_train_standard,y_train)
y_pred = clf.predict(x_test_standard)
accuracy_score(y_test,y_pred)
# Out:
# 0.8085308056872038

# %% [markdown]
# The SVC with linear,ploy and rbf kernel returns a best estimation of accuracy around 0.809

# %% [markdown]
# # Question 4

# %%
from sklearn.tree import DecisionTreeClassifier
# fit a model with optimal parameters from 3 to 6
# calculate the accuracy
score = 0
depth = 0
for i in range(3): 
    clf = DecisionTreeClassifier(max_depth = i+3)
    clf.fit(x_train_standard,y_train)
    y_pred = clf.predict(x_test_standard)
    new_score = accuracy_score(y_test,y_pred)
    if new_score > score:
        score = new_score
        depth = i + 1
print(score,depth,sep = ' ')
# Out:
# 0.8080568720379147 2

# %% [markdown]
# Optimal:
#
# max_depth = 2
#
# Accuracy = 0.8080568720379147

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
# fit a model with optimal parameters from 3 to 6
# calculate the accuracy
score = 0
depth = 0
for i in range(3): 
    clf = RandomForestClassifier(n_estimators = 10,max_depth = i+3)
    clf.fit(x_train_standard,y_train)
    y_pred = clf.predict(x_test_standard)
    new_score = accuracy_score(y_test,y_pred)
    if new_score > score:
        score = new_score
        depth = i + 1
print(score,depth,sep = ' ')
# Out:
# 0.8052132701421801 3

# %% [markdown]
#
# max_depth = 3
#
#
# Accuracy = 0.8052132701421801

# %%
# fit a model
# calculate the accuracy
clf = GradientBoostingClassifier().fit(x_train, y_train)
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8127962085308057

# %% [markdown]
# GBDT returned accuracy of 0.8127962085308057

# %% [markdown]
# # Question 5

# %% [markdown]
# All of the methods approximately returns the same accuracy of around 81%, but logistic regression with optimal regularization term returned a best result of around 81.5%.
#
# I would recommend Logistic Regression for its simplicity.
#
# My suggestions:
#
# **Use ensemble methods(Bagging) with Logistic regression to obtain better results**
#
# **Include interaction term between tenure and charges**
